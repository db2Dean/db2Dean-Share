# %% [markdown]
# # Query Data Virtualization using the REST API

# %% [markdown]
# The following notebook shows some examles of the same queries that I list in the September 2021 db2dean.com article on how to use the Data Virtualization REST API for querying virtual tables.  The difference is that the article calls the REST API using cURL and this notebook uses Python.
#
#
# You can find more information about the Db2/DV REST API at: https://www.ibm.com/support/producthub/db2/docs/content/SSEPGG_11.5.0/com.ibm.db2.luw.admin.rest.doc/doc/c_rest.html.
#
# This notebook is based on the one Peter Kohlmann provides in his Jupyter notebook on GitHub and uses much of the descriptive text used there.  He also provides many more examples that you can see here:  https://github.com/Db2-DTE-POC/CPDDVLAB/blob/master/Bonus%20Lab%20-%20Db2%20RESTful%20Endpoint%20Service.ipynb

# %% [markdown]
# ### Import the required programming libraries
# The requests library is the minimum required by Python to construct RESTful service calls. The Pandas library is used to format and manipulate JSON result sets as tables.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Authenticate to the End Point and Get a Token used for Querying Data
# So that you don't have to send your user id and password with every query, the REST endpoint will allow you to call it once and give  you a token to use in the queries instead.  The next set of steps will configure and call an API giving the End Point your Data Virtualization user id, pass word and other information to get a token that can be used to authenticate when you run the API go query the database.

# %% [markdown]
# ### Create the Header File required for getting an authetication token
# The RESTful call to the RESTful Endpoint service is contructed and transmitted as JSON. The first part of the JSON structure is the headers that define the content tyoe of the request.

# %% [markdown]
# Please note that you must configure the REST Endpoint as described in my Db2 Rest Endpoint article unless you are using the DV Endpoint deployed in your Cloud Pak for Data cluster.  In this case I am using my own endpoint an not the one in the CPD cluster.  http://www.db2dean.com/Previous/Db2RestEndpoint.html

# %%
headers = {
  "content-type": "application/json"
}

# %% [markdown]
# ### RESTful Host
# Define the host and port of the end point in a URL.    In this case I'm using my own endpoint

# %%
Db2RESTful = "http://192.168.0.14:50050"

# %% [markdown]
# ### API Authentication Service
# Each service has its own path in the RESTful call. For authentication we need to point to the `v1/auth` service.

# %%
API_Auth = "/v1/auth"

# %% [markdown]
# ### Authentication
# To authenticate to the RESTful service you must provide the connection information for the Data Virtualization database you want to query along with the userid and password that you are using to authenticate to that database. You can also provide an expiry time so that the access token that gets returned will be invalidated after that time period. In this example the token is good for 30 minutes.  Note that the database name in DV is always "BIGSQL".

# %%
body = {
  "dbParms": {
    "dbHost": "cpdmkt-cpd-cpdmkt.apps.cpd.170-224-72-131.nip.io",
    "dbName": "BIGSQL",
    "dbPort": 30753,
    "isSSLConnection": False,
    "username": "db2dean",
    "password": "db2dean_password"
  },
  "expiryTime": "30m"
}

# %% [markdown]
# ### API Service
# When communicating with the RESTful service, you must provide the name of the service that you want to interact with. In this case the authentication service is */v1/auth*.   When the cell below is run, the server will establish a connection to the database server.

# %%
# Use with HTTP call (when using endpoint container on my mac)
# Use when querying my local sample db or the DV database in the CPD cluster.
try:
    response = requests.post("{}{}".format(Db2RESTful,API_Auth), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

# %% [markdown]
# ### curl eqluivilant to the above call:
# token=`curl --header "Content-Type: application/json" \
#              -d '{"dbParms":{"dbHost": "cpdmkt-cpd-cpdmkt.apps.cpd.170-224-51-161.nip.io", \
# 		  "dbName": "BIGSQL","dbPort": 30753 ,\
#                   "isSSLConnection":false,"username": "db2dean","password": "password"},"expiryTime": "30m"}' \
#              http://192.168.0.14:50050/v1/auth`
#
# token2=`echo $token | awk 'BEGIN {FS = "\""} ; {print $4}'

# %% [markdown]
# A response code of 200 means that the authentication worked properly, otherwise the error that was generated is printed.

# %%
print(response)
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %% [markdown]
# The response includes a connection token that is reused in the queries below. It ensures secure a connection without requiring that you reenter a userid and password with each request.

# %%
if (response.status_code == 200):
  token = response.json()["token"]
  print("Token: {}".format(token))
else: 
  print(response.json()["errors"])
# Out:
# Token: eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJhZG1pbiI6dHJ1ZSwiY2xpZW50X2lkIjoiOGVjOGVkMTYtZDVlMC00MzBjLTk2ZWQtZjYxM2RkYzQ5OTdmIiwiZXhwIjoxNjMyNzc3ODk4LCJpc3MiOiJkYjJkZWFuIn0.Cr1s3X9AYQXMXFtd1OpEgRUh5Gs9etcSU9DANIva5sfFv7N9LirVj61FknZ_v4m4lRtDIiBf6x0BN8YhEYdXzwwizewgR71tI9xUjIbwN8Pdw9p35rbqz7Shd3_eRyifWdEw6aKhNEmHb0blL1V43t4sGB8bBtn7NQAl8F20TkaiYoJj0ZrUpGZzzZu90sXd2zGngFKKThqWc7ezqBU6iem-WlR3ylSsFQ1Z5vC5WLMHj995BG5CQCzxa5wvpYKoJvb3oHMCFXb_1Yrmd1o2aAAZCd_HW6eRaDovC7WfmrNG4nH3tYAJiVbuTRGm-FErThIqg1fK7DUeTjroOzCehA

# %% [markdown]
# ## The remaining steps configure variables and then query the database
# The standard header for all subsequent calls will use this format. It includes the access token.

# %%
headers = {
  "authorization": f"{token}",
  "content-type": "application/json"
}

# %% [markdown]
# ### API for Querying the virtual dataase
# Executing SQL requires the execsql service endpoint.

# %%
API_execsql = "/v1/services/execsql"

# %% [markdown]
# ### Format string to query a single virtual table in the database and run it

# %%
body = {
  "isQuery": True,
  "sqlStatement": "SELECT * \
    FROM DV.HOSPITAL_HCAHPS_DATA_PG",
  "sync": True
}

# %%
try:
    response = requests.post("{}{}".format(Db2RESTful,API_execsql), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

    # A response of 200 means success
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# #### The equivalent cURL of the above call is shown in this shell script
#
# ```
# myquery= "SELECT * \
#     FROM DV.HOSPITAL_HCAHPS_DATA_PG"
# ```
# ```
# curl --header "authorization: $token2" --header 'Content-Type: application/json' \
#       -d '{"isQuery": true,"sqlStatement": "'"$myquery"'" ,"sync": true}' \
#      http://192.168.0.14:50050/v1/services/execsql
# ```

# %% [markdown]
# Retrieve the results. The Dataframe class converts the json result set into a table. Dataframes can be used to further manipulate results in Python.

# %%
display(pd.DataFrame(response.json()['resultSet']))
# Out:
#              HCAHPS_MEASURE_ID PROVIDER_ID           county_name  \
# 0        H_COMP_4_LINEAR_SCORE       90008  DISTRICT OF COLUMBIA
# 1                H_COMP_4_SN_P       90008  DISTRICT OF COLUMBIA
# 2                 H_COMP_4_U_P      100009            MIAMI-DADE
# 3                 H_COMP_5_A_P      100009            MIAMI-DADE
# 4        H_COMP_5_LINEAR_SCORE      100009            MIAMI-DADE
# 5                H_COMP_5_SN_P      100009            MIAMI-DADE
# 6         H_COMP_5_STAR_RATING      100009            MIAMI-DADE
# 7                 H_COMP_5_U_P      100009            MIAMI-DADE
# 8        H_COMP_6_LINEAR_SCORE      100009            MIAMI-DADE
# 9                 H_COMP_6_N_P      100009            MIAMI-DADE
# 10        H_COMP_6_STAR_RATING      100009            MIAMI-DADE
# 11                H_COMP_6_Y_P      100009            MIAMI-DADE
# 12                  H_COMP_7_A      100009            MIAMI-DADE
# 13               H_COMP_7_D_SD      100009            MIAMI-DADE
# 14       H_COMP_7_LINEAR_SCORE      100009            MIAMI-DADE
# 15                 H_COMP_7_SA      100009            MIAMI-DADE
# 16        H_COMP_7_STAR_RATING      100009            MIAMI-DADE
# 17            H_HSP_RATING_0_6      100009            MIAMI-DADE
# 18            H_HSP_RATING_7_8      100009            MIAMI-DADE
# 19           H_HSP_RATING_9_10      100009            MIAMI-DADE
# 20   H_HSP_RATING_LINEAR_SCORE      100009            MIAMI-DADE
# 21    H_HSP_RATING_STAR_RATING      100009            MIAMI-DADE
# 22             H_QUIET_HSP_A_P      100009            MIAMI-DADE
# 23            H_QUIET_HSP_SN_P      100009            MIAMI-DADE
# 24             H_QUIET_HSP_U_P      100009            MIAMI-DADE
# 25        H_QUIET_LINEAR_SCORE      100009            MIAMI-DADE
# 26         H_QUIET_STAR_RATING      100009            MIAMI-DADE
# 27                 H_RECMND_DN      100009            MIAMI-DADE
# 28                 H_RECMND_DY      100009            MIAMI-DADE
# 29       H_RECMND_LINEAR_SCORE      100009            MIAMI-DADE
# ..                         ...         ...                   ...
# 370      H_COMP_5_LINEAR_SCORE      100063                 PASCO
# 371              H_COMP_5_SN_P      100063                 PASCO
# 372       H_COMP_5_STAR_RATING      100063                 PASCO
# 373               H_COMP_5_U_P      100063                 PASCO
# 374      H_COMP_6_LINEAR_SCORE      100063                 PASCO
# 375               H_COMP_6_N_P      100063                 PASCO
# 376       H_COMP_6_STAR_RATING      100063                 PASCO
# 377               H_COMP_6_Y_P      100063                 PASCO
# 378                 H_COMP_7_A      100063                 PASCO
# 379              H_COMP_7_D_SD      100063                 PASCO
# 380      H_COMP_7_LINEAR_SCORE      100063                 PASCO
# 381                H_COMP_7_SA      100063                 PASCO
# 382       H_COMP_7_STAR_RATING      100063                 PASCO
# 383           H_HSP_RATING_0_6      100063                 PASCO
# 384           H_HSP_RATING_7_8      100063                 PASCO
# 385          H_HSP_RATING_9_10      100063                 PASCO
# 386  H_HSP_RATING_LINEAR_SCORE      100063                 PASCO
# 387   H_HSP_RATING_STAR_RATING      100063                 PASCO
# 388            H_QUIET_HSP_A_P      100063                 PASCO
# 389           H_QUIET_HSP_SN_P      100063                 PASCO
# 390            H_QUIET_HSP_U_P      100063                 PASCO
# 391       H_QUIET_LINEAR_SCORE      100063                 PASCO
# 392        H_QUIET_STAR_RATING      100063                 PASCO
# 393                H_RECMND_DN      100063                 PASCO
# 394                H_RECMND_DY      100063                 PASCO
# 395      H_RECMND_LINEAR_SCORE      100063                 PASCO
# 396                H_RECMND_PY      100063                 PASCO
# 397       H_RECMND_STAR_RATING      100063                 PASCO
# 398              H_STAR_RATING      100067              PINELLAS
# 399            H_CLEAN_HSP_A_P      100067              PINELLAS
#
#                              hcahps_answer_description hcahps_answer_percent  \
# 0                  Pain management - linear mean score        Not Applicable
# 1      Pain was "sometimes" or "never" well controlled                    17
# 2                   Pain was "usually" well controlled                    23
# 3                             Staff "always" explained                    60
# 4    Communication about medicines - linear mean score        Not Applicable
# 5               Staff "sometimes" or "never" explained                    23
# 6          Communication about medicines - star rating        Not Applicable
# 7                            Staff "usually" explained                    17
# 8            Discharge information - linear mean score        Not Applicable
# 9    No, staff "did not" give patients this informa...                    17
# 10                 Discharge information - star rating        Not Applicable
# 11     Yes, staff "did" give patients this information                    83
# 12   Patients who �Agree� they understood their car...                    38
# 13   Patients who �Disagree� or �Strongly Disagree�...                     8
# 14                 Care transition - linear mean score        Not Applicable
# 15   Patients who �Strongly Agree� they understood ...                    54
# 16                       Care transition - star rating        Not Applicable
# 17    Patients who gave a rating of "6" or lower (low)                    13
# 18   Patients who gave a rating of "7" or "8" (medium)                    22
# 19    Patients who gave a rating of "9" or "10" (high)                    65
# 20         Overall hospital rating - linear mean score        Not Applicable
# 21               Overall hospital rating - star rating        Not Applicable
# 22                             "Always" quiet at night                    61
# 23               "Sometimes" or "never" quiet at night                    12
# 24                            "Usually" quiet at night                    27
# 25                       Quietness - linear mean score        Not Applicable
# 26                             Quietness - star rating        Not Applicable
# 27   "NO", patients would not recommend the hospita...                     8
# 28   "YES", patients would definitely recommend the...                    69
# 29              Recommend hospital - linear mean score        Not Applicable
# ..                                                 ...                   ...
# 370  Communication about medicines - linear mean score        Not Applicable
# 371             Staff "sometimes" or "never" explained                    15
# 372        Communication about medicines - star rating        Not Applicable
# 373                          Staff "usually" explained                    17
# 374          Discharge information - linear mean score        Not Applicable
# 375  No, staff "did not" give patients this informa...                    11
# 376                Discharge information - star rating        Not Applicable
# 377    Yes, staff "did" give patients this information                    89
# 378  Patients who �Agree� they understood their car...                    40
# 379  Patients who �Disagree� or �Strongly Disagree�...                     5
# 380                Care transition - linear mean score        Not Applicable
# 381  Patients who �Strongly Agree� they understood ...                    55
# 382                      Care transition - star rating        Not Applicable
# 383   Patients who gave a rating of "6" or lower (low)                     7
# 384  Patients who gave a rating of "7" or "8" (medium)                    19
# 385   Patients who gave a rating of "9" or "10" (high)                    74
# 386        Overall hospital rating - linear mean score        Not Applicable
# 387              Overall hospital rating - star rating        Not Applicable
# 388                            "Always" quiet at night                    52
# 389              "Sometimes" or "never" quiet at night                    13
# 390                           "Usually" quiet at night                    35
# 391                      Quietness - linear mean score        Not Applicable
# 392                            Quietness - star rating        Not Applicable
# 393  "NO", patients would not recommend the hospita...                     5
# 394  "YES", patients would definitely recommend the...                    77
# 395             Recommend hospital - linear mean score        Not Applicable
# 396  "YES", patients would probably recommend the h...                    18
# 397                   Recommend hospital - star rating        Not Applicable
# 398                                Summary star rating        Not Applicable
# 399                            Room was "always" clean                    65
#
#     hcahps_answer_percent_footnote hcahps_linear_mean_value  \
# 0                                                        81
# 1                                            Not Applicable
# 2                                            Not Applicable
# 3                                            Not Applicable
# 4                                                        74
# 5                                            Not Applicable
# 6                                            Not Applicable
# 7                                            Not Applicable
# 8                                                        83
# 9                                            Not Applicable
# 10                                           Not Applicable
# 11                                           Not Applicable
# 12                                           Not Applicable
# 13                                           Not Applicable
# 14                                                       81
# 15                                           Not Applicable
# 16                                           Not Applicable
# 17                                           Not Applicable
# 18                                           Not Applicable
# 19                                           Not Applicable
# 20                                                       85
# 21                                           Not Applicable
# 22                                           Not Applicable
# 23                                           Not Applicable
# 24                                           Not Applicable
# 25                                                       82
# 26                                           Not Applicable
# 27                                           Not Applicable
# 28                                           Not Applicable
# 29                                                       86
# ..                             ...                      ...
# 370                                                      82
# 371                                          Not Applicable
# 372                                          Not Applicable
# 373                                          Not Applicable
# 374                                                      89
# 375                                          Not Applicable
# 376                                          Not Applicable
# 377                                          Not Applicable
# 378                                          Not Applicable
# 379                                          Not Applicable
# 380                                                      83
# 381                                          Not Applicable
# 382                                          Not Applicable
# 383                                          Not Applicable
# 384                                          Not Applicable
# 385                                          Not Applicable
# 386                                                      90
# 387                                          Not Applicable
# 388                                          Not Applicable
# 389                                          Not Applicable
# 390                                          Not Applicable
# 391                                                      79
# 392                                          Not Applicable
# 393                                          Not Applicable
# 394                                          Not Applicable
# 395                                                      90
# 396                                          Not Applicable
# 397                                          Not Applicable
# 398                                          Not Applicable
# 399                                          Not Applicable
#
#                                        hcahps_question  \
# 0                  Pain management - linear mean score
# 1    Patients who reported that their pain was "Som...
# 2    Patients who reported that their pain was "Usu...
# 3    Patients who reported that staff "Always" expl...
# 4    Communication about medicines - linear mean score
# 5    Patients who reported that staff "Sometimes" o...
# 6          Communication about medicines - star rating
# 7    Patients who reported that staff "Usually" exp...
# 8            Discharge information - linear mean score
# 9    Patients who reported that NO, they were not g...
# 10                 Discharge information - star rating
# 11   Patients who reported that YES, they were give...
# 12   Patients who �Agree� they understood their car...
# 13   Patients who �Disagree� or �Strongly Disagree�...
# 14                 Care transition - linear mean score
# 15   Patients who "Strongly Agree" they understood ...
# 16                       Care transition - star rating
# 17   Patients who gave their hospital a rating of 6...
# 18   Patients who gave their hospital a rating of 7...
# 19   Patients who gave their hospital a rating of 9...
# 20         Overall hospital rating - linear mean score
# 21               Overall hospital rating - star rating
# 22   Patients who reported that the area around the...
# 23   Patients who reported that the area around the...
# 24   Patients who reported that the area around the...
# 25                       Quietness - linear mean score
# 26                             Quietness - star rating
# 27   Patients who reported NO, they would probably ...
# 28   Patients who reported YES, they would definite...
# 29              Recommend hospital - linear mean score
# ..                                                 ...
# 370  Communication about medicines - linear mean score
# 371  Patients who reported that staff "Sometimes" o...
# 372        Communication about medicines - star rating
# 373  Patients who reported that staff "Usually" exp...
# 374          Discharge information - linear mean score
# 375  Patients who reported that NO, they were not g...
# 376                Discharge information - star rating
# 377  Patients who reported that YES, they were give...
# 378  Patients who �Agree� they understood their car...
# 379  Patients who �Disagree� or �Strongly Disagree�...
# 380                Care transition - linear mean score
# 381  Patients who "Strongly Agree" they understood ...
# 382                      Care transition - star rating
# 383  Patients who gave their hospital a rating of 6...
# 384  Patients who gave their hospital a rating of 7...
# 385  Patients who gave their hospital a rating of 9...
# 386        Overall hospital rating - linear mean score
# 387              Overall hospital rating - star rating
# 388  Patients who reported that the area around the...
# 389  Patients who reported that the area around the...
# 390  Patients who reported that the area around the...
# 391                      Quietness - linear mean score
# 392                            Quietness - star rating
# 393  Patients who reported NO, they would probably ...
# 394  Patients who reported YES, they would definite...
# 395             Recommend hospital - linear mean score
# 396  Patients who reported YES, they would probably...
# 397                   Recommend hospital - star rating
# 398                                Summary star rating
# 399  Patients who reported that their room and bath...
#
#                        hospital_name
# 0              UNITED MEDICAL CENTER
# 1              UNITED MEDICAL CENTER
# 2       UNIVERSITY OF MIAMI HOSPITAL
# 3       UNIVERSITY OF MIAMI HOSPITAL
# 4       UNIVERSITY OF MIAMI HOSPITAL
# 5       UNIVERSITY OF MIAMI HOSPITAL
# 6       UNIVERSITY OF MIAMI HOSPITAL
# 7       UNIVERSITY OF MIAMI HOSPITAL
# 8       UNIVERSITY OF MIAMI HOSPITAL
# 9       UNIVERSITY OF MIAMI HOSPITAL
# 10      UNIVERSITY OF MIAMI HOSPITAL
# 11      UNIVERSITY OF MIAMI HOSPITAL
# 12      UNIVERSITY OF MIAMI HOSPITAL
# 13      UNIVERSITY OF MIAMI HOSPITAL
# 14      UNIVERSITY OF MIAMI HOSPITAL
# 15      UNIVERSITY OF MIAMI HOSPITAL
# 16      UNIVERSITY OF MIAMI HOSPITAL
# 17      UNIVERSITY OF MIAMI HOSPITAL
# 18      UNIVERSITY OF MIAMI HOSPITAL
# 19      UNIVERSITY OF MIAMI HOSPITAL
# 20      UNIVERSITY OF MIAMI HOSPITAL
# 21      UNIVERSITY OF MIAMI HOSPITAL
# 22      UNIVERSITY OF MIAMI HOSPITAL
# 23      UNIVERSITY OF MIAMI HOSPITAL
# 24      UNIVERSITY OF MIAMI HOSPITAL
# 25      UNIVERSITY OF MIAMI HOSPITAL
# 26      UNIVERSITY OF MIAMI HOSPITAL
# 27      UNIVERSITY OF MIAMI HOSPITAL
# 28      UNIVERSITY OF MIAMI HOSPITAL
# 29      UNIVERSITY OF MIAMI HOSPITAL
# ..                               ...
# 370  MORTON PLANT NORTH BAY HOSPITAL
# 371  MORTON PLANT NORTH BAY HOSPITAL
# 372  MORTON PLANT NORTH BAY HOSPITAL
# 373  MORTON PLANT NORTH BAY HOSPITAL
# 374  MORTON PLANT NORTH BAY HOSPITAL
# 375  MORTON PLANT NORTH BAY HOSPITAL
# 376  MORTON PLANT NORTH BAY HOSPITAL
# 377  MORTON PLANT NORTH BAY HOSPITAL
# 378  MORTON PLANT NORTH BAY HOSPITAL
# 379  MORTON PLANT NORTH BAY HOSPITAL
# 380  MORTON PLANT NORTH BAY HOSPITAL
# 381  MORTON PLANT NORTH BAY HOSPITAL
# 382  MORTON PLANT NORTH BAY HOSPITAL
# 383  MORTON PLANT NORTH BAY HOSPITAL
# 384  MORTON PLANT NORTH BAY HOSPITAL
# 385  MORTON PLANT NORTH BAY HOSPITAL
# 386  MORTON PLANT NORTH BAY HOSPITAL
# 387  MORTON PLANT NORTH BAY HOSPITAL
# 388  MORTON PLANT NORTH BAY HOSPITAL
# 389  MORTON PLANT NORTH BAY HOSPITAL
# 390  MORTON PLANT NORTH BAY HOSPITAL
# 391  MORTON PLANT NORTH BAY HOSPITAL
# 392  MORTON PLANT NORTH BAY HOSPITAL
# 393  MORTON PLANT NORTH BAY HOSPITAL
# 394  MORTON PLANT NORTH BAY HOSPITAL
# 395  MORTON PLANT NORTH BAY HOSPITAL
# 396  MORTON PLANT NORTH BAY HOSPITAL
# 397  MORTON PLANT NORTH BAY HOSPITAL
# 398             ST ANTHONYS HOSPITAL
# 399             ST ANTHONYS HOSPITAL
#
# [400 rows x 9 columns]

# %%
response.json()
# Out:
# {'jobStatus': 4,
#  'jobStatusDescription': 'Job is complete',
#  'resultSet': [{'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'PROVIDER_ID': '90008',
#    'county_name': 'DISTRICT OF COLUMBIA',
#    'hcahps_answer_description': 'Pain management - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '81',
#    'hcahps_question': 'Pain management - linear mean score',
#    'hospital_name': 'UNITED MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_SN_P',
#    'PROVIDER_ID': '90008',
#    'county_name': 'DISTRICT OF COLUMBIA',
#    'hcahps_answer_description': 'Pain was "sometimes" or "never" well controlled',
#    'hcahps_answer_percent': '17',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Sometimes" or "Never" well controlled',
#    'hospital_name': 'UNITED MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_U_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Pain was "usually" well controlled',
#    'hcahps_answer_percent': '23',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Usually" well controlled',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_A_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Staff "always" explained',
#    'hcahps_answer_percent': '60',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Always" explained about medicines before giving it to them',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_LINEAR_SCORE',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Communication about medicines - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '74',
#    'hcahps_question': 'Communication about medicines - linear mean score',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_SN_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Staff "sometimes" or "never" explained',
#    'hcahps_answer_percent': '23',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Sometimes" or "Never" explained about medicines before giving it to them',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_STAR_RATING',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Communication about medicines - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Communication about medicines - star rating',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_U_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Staff "usually" explained',
#    'hcahps_answer_percent': '17',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Usually" explained about medicines before giving it to them',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_LINEAR_SCORE',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Discharge information - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '83',
#    'hcahps_question': 'Discharge information - linear mean score',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_N_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'No, staff "did not" give patients this information',
#    'hcahps_answer_percent': '17',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that NO, they were not given information about what to do during their recovery at home',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_STAR_RATING',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Discharge information - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Discharge information - star rating',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_Y_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Yes, staff "did" give patients this information',
#    'hcahps_answer_percent': '83',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that YES, they were given information about what to do during their recovery at home',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_A',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Patients who �Agree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '38',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who �Agree� they understood their care when they left the hospital',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_D_SD',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Patients who �Disagree� or �Strongly Disagree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '8',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who �Disagree� or �Strongly Disagree� they understood their care when they left the hospital',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_LINEAR_SCORE',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Care transition - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '81',
#    'hcahps_question': 'Care transition - linear mean score',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_SA',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Patients who �Strongly Agree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '54',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who "Strongly Agree" they understood their care when they left the hospital',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_STAR_RATING',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Care transition - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Care transition - star rating',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_0_6',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Patients who gave a rating of "6" or lower (low)',
#    'hcahps_answer_percent': '13',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 6 or lower on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_7_8',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Patients who gave a rating of "7" or "8" (medium)',
#    'hcahps_answer_percent': '22',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 7 or 8 on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_9_10',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Patients who gave a rating of "9" or "10" (high)',
#    'hcahps_answer_percent': '65',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_LINEAR_SCORE',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Overall hospital rating - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '85',
#    'hcahps_question': 'Overall hospital rating - linear mean score',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_STAR_RATING',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Overall hospital rating - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Overall hospital rating - star rating',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_A_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': '"Always" quiet at night',
#    'hcahps_answer_percent': '61',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Always" quiet at night',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_SN_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': '"Sometimes" or "never" quiet at night',
#    'hcahps_answer_percent': '12',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Sometimes" or "Never" quiet at night',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_U_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': '"Usually" quiet at night',
#    'hcahps_answer_percent': '27',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Usually" quiet at night',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_LINEAR_SCORE',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Quietness - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '82',
#    'hcahps_question': 'Quietness - linear mean score',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_STAR_RATING',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Quietness - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Quietness - star rating',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_DN',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': '"NO", patients would not recommend the hospital (they probably would not or definitely would not recommend it)',
#    'hcahps_answer_percent': '8',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported NO, they would probably not or definitely not recommend the hospital',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_DY',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': '"YES", patients would definitely recommend the hospital',
#    'hcahps_answer_percent': '69',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported YES, they would definitely recommend the hospital',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_LINEAR_SCORE',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Recommend hospital - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '86',
#    'hcahps_question': 'Recommend hospital - linear mean score',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_PY',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': '"YES", patients would probably recommend the hospital',
#    'hcahps_answer_percent': '23',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported YES, they would probably recommend the hospital',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_STAR_RATING',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Recommend hospital - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Recommend hospital - star rating',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Summary star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Summary star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_HSP_A_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Room was "always" clean',
#    'hcahps_answer_percent': '69',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their room and bathroom were "Always" clean',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_HSP_SN_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Room was "sometimes" or "never" clean',
#    'hcahps_answer_percent': '10',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their room and bathroom were "Sometimes" or "Never" clean',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_LINEAR_SCORE',
#    'PROVIDER_ID': '100030',
#    'county_name': 'ORANGE',
#    'hcahps_answer_description': 'Quietness - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '84',
#    'hcahps_question': 'Quietness - linear mean score',
#    'hospital_name': 'HEALTH CENTRAL'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_HSP_U_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Room was "usually" clean',
#    'hcahps_answer_percent': '21',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their room and bathroom were "Usually" clean',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Cleanliness - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '86',
#    'hcahps_question': 'Cleanliness - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Cleanliness - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Cleanliness - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_A_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Nurses "always" communicated well',
#    'hcahps_answer_percent': '77',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their nurses "Always" communicated well',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Nurse communication - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '90',
#    'hcahps_question': 'Nurse communication - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_SN_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Nurses "sometimes" or "never" communicated well',
#    'hcahps_answer_percent': '5',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their nurses "Sometimes" or "Never" communicated well',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Nurse communication - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Nurse communication - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_U_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Nurses "usually" communicated well',
#    'hcahps_answer_percent': '18',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their nurses "Usually" communicated well',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_A_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Doctors "always" communicated well',
#    'hcahps_answer_percent': '75',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their doctors "Always" communicated well',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Doctor communication - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '89',
#    'hcahps_question': 'Doctor communication - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_SN_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Doctors "sometimes" or "never" communicated well',
#    'hcahps_answer_percent': '6',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their doctors "Sometimes" or "Never" communicated well',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Doctor communication - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Doctor communication - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_U_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Doctors "usually" communicated well',
#    'hcahps_answer_percent': '19',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their doctors "Usually" communicated well',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_3_A_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients "always" received help as soon as they wanted',
#    'hcahps_answer_percent': '60',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that they "Always" received help as soon as they wanted',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_3_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Staff responsiveness - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '83',
#    'hcahps_question': 'Staff responsiveness - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_3_SN_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients "sometimes" or "never" received help as soon as they wanted',
#    'hcahps_answer_percent': '10',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that they "Sometimes" or "Never" received help as soon as they wanted',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_3_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Staff responsiveness - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Staff responsiveness - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_3_U_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients "usually" received help as soon as they wanted',
#    'hcahps_answer_percent': '30',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that they "Usually" received help as soon as they wanted',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_A_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Pain was "always" well controlled',
#    'hcahps_answer_percent': '67',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Always" well controlled',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Pain management - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '86',
#    'hcahps_question': 'Pain management - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_SN_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Pain was "sometimes" or "never" well controlled',
#    'hcahps_answer_percent': '7',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Sometimes" or "Never" well controlled',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Pain management - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Pain management - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_U_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Pain was "usually" well controlled',
#    'hcahps_answer_percent': '26',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Usually" well controlled',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_A_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Staff "always" explained',
#    'hcahps_answer_percent': '61',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Always" explained about medicines before giving it to them',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Communication about medicines - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '76',
#    'hcahps_question': 'Communication about medicines - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_SN_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Staff "sometimes" or "never" explained',
#    'hcahps_answer_percent': '21',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Sometimes" or "Never" explained about medicines before giving it to them',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Communication about medicines - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Communication about medicines - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_U_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Staff "usually" explained',
#    'hcahps_answer_percent': '18',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Usually" explained about medicines before giving it to them',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Discharge information - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '88',
#    'hcahps_question': 'Discharge information - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_N_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'No, staff "did not" give patients this information',
#    'hcahps_answer_percent': '12',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that NO, they were not given information about what to do during their recovery at home',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Discharge information - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Discharge information - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_Y_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Yes, staff "did" give patients this information',
#    'hcahps_answer_percent': '88',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that YES, they were given information about what to do during their recovery at home',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_A',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients who �Agree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '43',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who �Agree� they understood their care when they left the hospital',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_D_SD',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients who �Disagree� or �Strongly Disagree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '6',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who �Disagree� or �Strongly Disagree� they understood their care when they left the hospital',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Care transition - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '81',
#    'hcahps_question': 'Care transition - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_SA',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients who �Strongly Agree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '51',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who "Strongly Agree" they understood their care when they left the hospital',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Care transition - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Care transition - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_0_6',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients who gave a rating of "6" or lower (low)',
#    'hcahps_answer_percent': '9',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 6 or lower on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_7_8',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients who gave a rating of "7" or "8" (medium)',
#    'hcahps_answer_percent': '22',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 7 or 8 on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_9_10',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Patients who gave a rating of "9" or "10" (high)',
#    'hcahps_answer_percent': '69',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Overall hospital rating - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '88',
#    'hcahps_question': 'Overall hospital rating - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Overall hospital rating - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Overall hospital rating - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_A_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': '"Always" quiet at night',
#    'hcahps_answer_percent': '57',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Always" quiet at night',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_SN_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': '"Sometimes" or "never" quiet at night',
#    'hcahps_answer_percent': '12',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Sometimes" or "Never" quiet at night',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_U_P',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': '"Usually" quiet at night',
#    'hcahps_answer_percent': '31',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Usually" quiet at night',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Quietness - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '81',
#    'hcahps_question': 'Quietness - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Quietness - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Quietness - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_DN',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': '"NO", patients would not recommend the hospital (they probably would not or definitely would not recommend it)',
#    'hcahps_answer_percent': '6',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported NO, they would probably not or definitely not recommend the hospital',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_DY',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': '"YES", patients would definitely recommend the hospital',
#    'hcahps_answer_percent': '73',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported YES, they would definitely recommend the hospital',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_LINEAR_SCORE',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Recommend hospital - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '88',
#    'hcahps_question': 'Recommend hospital - linear mean score',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_PY',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': '"YES", patients would probably recommend the hospital',
#    'hcahps_answer_percent': '21',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported YES, they would probably recommend the hospital',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_STAR_RATING',
#    'PROVIDER_ID': '100012',
#    'county_name': 'LEE',
#    'hcahps_answer_description': 'Recommend hospital - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Recommend hospital - star rating',
#    'hospital_name': 'LEE MEMORIAL HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_STAR_RATING',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Summary star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Summary star rating',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_HSP_A_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Room was "always" clean',
#    'hcahps_answer_percent': '63',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their room and bathroom were "Always" clean',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_HSP_SN_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Room was "sometimes" or "never" clean',
#    'hcahps_answer_percent': '15',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their room and bathroom were "Sometimes" or "Never" clean',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_HSP_U_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Room was "usually" clean',
#    'hcahps_answer_percent': '22',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their room and bathroom were "Usually" clean',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_LINEAR_SCORE',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Cleanliness - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '82',
#    'hcahps_question': 'Cleanliness - linear mean score',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_STAR_RATING',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Cleanliness - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Cleanliness - star rating',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_A_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Nurses "always" communicated well',
#    'hcahps_answer_percent': '73',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their nurses "Always" communicated well',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_LINEAR_SCORE',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Nurse communication - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '89',
#    'hcahps_question': 'Nurse communication - linear mean score',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_SN_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Nurses "sometimes" or "never" communicated well',
#    'hcahps_answer_percent': '6',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their nurses "Sometimes" or "Never" communicated well',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_STAR_RATING',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Nurse communication - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Nurse communication - star rating',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_1_U_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Nurses "usually" communicated well',
#    'hcahps_answer_percent': '21',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their nurses "Usually" communicated well',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_A_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Doctors "always" communicated well',
#    'hcahps_answer_percent': '71',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their doctors "Always" communicated well',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_LINEAR_SCORE',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Doctor communication - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '87',
#    'hcahps_question': 'Doctor communication - linear mean score',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_SN_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Doctors "sometimes" or "never" communicated well',
#    'hcahps_answer_percent': '9',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their doctors "Sometimes" or "Never" communicated well',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_STAR_RATING',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Doctor communication - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Doctor communication - star rating',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_2_U_P',
#    'PROVIDER_ID': '100014',
#    'county_name': 'VOLUSIA',
#    'hcahps_answer_description': 'Doctors "usually" communicated well',
#    'hcahps_answer_percent': '20',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their doctors "Usually" communicated well',
#    'hospital_name': 'FLORIDA HOSPITAL NEW SMYRNA'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_3_STAR_RATING',
#    'PROVIDER_ID': '100029',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Staff responsiveness - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Staff responsiveness - star rating',
#    'hospital_name': 'NORTH SHORE MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_3_U_P',
#    'PROVIDER_ID': '100029',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Patients "usually" received help as soon as they wanted',
#    'hcahps_answer_percent': '25',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that they "Usually" received help as soon as they wanted',
#    'hospital_name': 'NORTH SHORE MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_A_P',
#    'PROVIDER_ID': '100029',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Pain was "always" well controlled',
#    'hcahps_answer_percent': '68',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Always" well controlled',
#    'hospital_name': 'NORTH SHORE MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'PROVIDER_ID': '100029',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Pain management - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '85',
#    'hcahps_question': 'Pain management - linear mean score',
#    'hospital_name': 'NORTH SHORE MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_SN_P',
#    'PROVIDER_ID': '100029',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Pain was "sometimes" or "never" well controlled',
#    'hcahps_answer_percent': '11',
#    'hcahps_answer_percent_footnote': '',
# ...
#    'hcahps_question': 'Patients who reported that their pain was "Always" well controlled',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Pain management - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '87',
#    'hcahps_question': 'Pain management - linear mean score',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_SN_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Pain was "sometimes" or "never" well controlled',
#    'hcahps_answer_percent': '7',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Sometimes" or "Never" well controlled',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_STAR_RATING',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Pain management - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Pain management - star rating',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_U_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Pain was "usually" well controlled',
#    'hcahps_answer_percent': '23',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Usually" well controlled',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_A_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Staff "always" explained',
#    'hcahps_answer_percent': '68',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Always" explained about medicines before giving it to them',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_LINEAR_SCORE',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Communication about medicines - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '82',
#    'hcahps_question': 'Communication about medicines - linear mean score',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_SN_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Staff "sometimes" or "never" explained',
#    'hcahps_answer_percent': '15',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Sometimes" or "Never" explained about medicines before giving it to them',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_STAR_RATING',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Communication about medicines - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Communication about medicines - star rating',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_5_U_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Staff "usually" explained',
#    'hcahps_answer_percent': '17',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that staff "Usually" explained about medicines before giving it to them',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_LINEAR_SCORE',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Discharge information - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '89',
#    'hcahps_question': 'Discharge information - linear mean score',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_N_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'No, staff "did not" give patients this information',
#    'hcahps_answer_percent': '11',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that NO, they were not given information about what to do during their recovery at home',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_STAR_RATING',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Discharge information - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Discharge information - star rating',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_6_Y_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Yes, staff "did" give patients this information',
#    'hcahps_answer_percent': '89',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that YES, they were given information about what to do during their recovery at home',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_A',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Patients who �Agree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '40',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who �Agree� they understood their care when they left the hospital',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_D_SD',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Patients who �Disagree� or �Strongly Disagree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '5',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who �Disagree� or �Strongly Disagree� they understood their care when they left the hospital',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_LINEAR_SCORE',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Care transition - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '83',
#    'hcahps_question': 'Care transition - linear mean score',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_SA',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Patients who �Strongly Agree� they understood their care when they left the hospital',
#    'hcahps_answer_percent': '55',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who "Strongly Agree" they understood their care when they left the hospital',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_7_STAR_RATING',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Care transition - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Care transition - star rating',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_0_6',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Patients who gave a rating of "6" or lower (low)',
#    'hcahps_answer_percent': '7',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 6 or lower on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_7_8',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Patients who gave a rating of "7" or "8" (medium)',
#    'hcahps_answer_percent': '19',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 7 or 8 on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_9_10',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Patients who gave a rating of "9" or "10" (high)',
#    'hcahps_answer_percent': '74',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who gave their hospital a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_LINEAR_SCORE',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Overall hospital rating - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '90',
#    'hcahps_question': 'Overall hospital rating - linear mean score',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_HSP_RATING_STAR_RATING',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Overall hospital rating - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Overall hospital rating - star rating',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_A_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': '"Always" quiet at night',
#    'hcahps_answer_percent': '52',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Always" quiet at night',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_SN_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': '"Sometimes" or "never" quiet at night',
#    'hcahps_answer_percent': '13',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Sometimes" or "Never" quiet at night',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_HSP_U_P',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': '"Usually" quiet at night',
#    'hcahps_answer_percent': '35',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that the area around their room was "Usually" quiet at night',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_LINEAR_SCORE',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Quietness - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '79',
#    'hcahps_question': 'Quietness - linear mean score',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_QUIET_STAR_RATING',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Quietness - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Quietness - star rating',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_DN',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': '"NO", patients would not recommend the hospital (they probably would not or definitely would not recommend it)',
#    'hcahps_answer_percent': '5',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported NO, they would probably not or definitely not recommend the hospital',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_DY',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': '"YES", patients would definitely recommend the hospital',
#    'hcahps_answer_percent': '77',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported YES, they would definitely recommend the hospital',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_LINEAR_SCORE',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Recommend hospital - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '90',
#    'hcahps_question': 'Recommend hospital - linear mean score',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_PY',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': '"YES", patients would probably recommend the hospital',
#    'hcahps_answer_percent': '18',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported YES, they would probably recommend the hospital',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_RECMND_STAR_RATING',
#    'PROVIDER_ID': '100063',
#    'county_name': 'PASCO',
#    'hcahps_answer_description': 'Recommend hospital - star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Recommend hospital - star rating',
#    'hospital_name': 'MORTON PLANT NORTH BAY HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_STAR_RATING',
#    'PROVIDER_ID': '100067',
#    'county_name': 'PINELLAS',
#    'hcahps_answer_description': 'Summary star rating',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Summary star rating',
#    'hospital_name': 'ST ANTHONYS HOSPITAL'},
#   {'HCAHPS_MEASURE_ID': 'H_CLEAN_HSP_A_P',
#    'PROVIDER_ID': '100067',
#    'county_name': 'PINELLAS',
#    'hcahps_answer_description': 'Room was "always" clean',
#    'hcahps_answer_percent': '65',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their room and bathroom were "Always" clean',
#    'hospital_name': 'ST ANTHONYS HOSPITAL'}],
#  'rowCount': 400}

# %% [markdown]
# ### Format string to join multiple tables and run it

# %%
body = {
  "isQuery": True,
  "sqlStatement": "select postgres.hcahps_measure_id \
              , db2edw.county_name as County \
              , sandbox.number_of_readmissions \
           from DV.HOSPITAL_HCAHPS_DATA_PG postgres \
              , DV.HOSPITAL_INFO_EDW db2edw \
              , DV.HOSPITAL_READMISSION_DB2S sandbox \
          where varchar(postgres.provider_id) = db2edw.provider_id \
            and db2edw.provider_id = sandbox.provider_number \
          fetch first 3 rows only",
  "sync": True
}

# %% [markdown]
# Retrieve the results. The Dataframe class converts the json result set into a table. Dataframes can be used to further manipulate results in Python.

# %%
# Use with HTTP call when using endpoint container on my mac
# This end point tals to my local DB, DV or any other database defined in the DB2RESTful set up above.
try:
    response = requests.post("{}{}".format(Db2RESTful,API_execsql), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

    # A response of 200 means success
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# The equivalent cURL call is:
#
# ```
# myquery="select postgres.hcahps_measure_id \
#               , db2edw.county_name as County \
#               , sandbox.number_of_readmissions \
#            from DV.HOSPITAL_HCAHPS_DATA_PG postgres \
#               , DV.HOSPITAL_INFO_EDW db2edw \
#               , DV.HOSPITAL_READMISSION_DB2S sandbox \
#           where varchar(postgres.provider_id) = db2edw.provider_id \
#             and db2edw.provider_id = sandbox.provider_number \
#           fetch first 3 rows only"
#
# curl --header "authorization: $token2" --header 'Content-Type: application/json' \
#       -d '{"isQuery": true,"sqlStatement": "'"$myquery"'" ,"sync": true}' \
#      http://192.168.0.14:50050/v1/services/execsql
# ```

# %%
display(pd.DataFrame(response.json()['resultSet']))
# Out:
#                  COUNTY      HCAHPS_MEASURE_ID  NUMBER_OF_READMISSIONS
# 0  DISTRICT OF COLUMBIA  H_COMP_4_LINEAR_SCORE                      40
# 1  DISTRICT OF COLUMBIA  H_COMP_4_LINEAR_SCORE                      44
# 2  DISTRICT OF COLUMBIA  H_COMP_4_LINEAR_SCORE                      61

# %%
response.json()
# Out:
# {'jobStatus': 4,
#  'jobStatusDescription': 'Job is complete',
#  'resultSet': [{'COUNTY': 'DISTRICT OF COLUMBIA',
#    'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'NUMBER_OF_READMISSIONS': 40},
#   {'COUNTY': 'DISTRICT OF COLUMBIA',
#    'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'NUMBER_OF_READMISSIONS': 44},
#   {'COUNTY': 'DISTRICT OF COLUMBIA',
#    'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'NUMBER_OF_READMISSIONS': 61}],
#  'rowCount': 3}

# %% [markdown]
# ### Format string to describe a virtual table

# %%
body = {
  "isQuery": True,
  "sqlStatement": "CALL sysproc.admin_cmd('describe table DV.HOSP_INFO_READMIT_VIEW')",
  "sync": True
}

# %%
# Use with HTTP call when using endpoint container on my mac
# This end point tals to my local DB, DV or any other database defined in the DB2RESTful set up above.
try:
    response = requests.post("{}{}".format(Db2RESTful,API_execsql), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

    # A response of 200 means success
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# The equivalent cURL call is:
# ```
# myquery="CALL sysproc.admin_cmd('describe table DV.HOSP_INFO_READMIT_VIEW ')"
# curl --header "authorization: $token2" --header 'Content-Type: application/json' \
#       -d '{"isQuery": true,"sqlStatement": "'"$myquery"'" ,"sync": true}' \
#      http://192.168.0.14:50050/v1/services/execsql
# ```

# %% [markdown]
# Retrieve the results. The Dataframe class converts the json result set into a table. Dataframes can be used to further manipulate results in Python.

# %%
display(pd.DataFrame(response.json()['resultSet']))
# Out:
#                                               COLNAME  LENGTH NULLABLE  SCALE  \
# 0                                         PROVIDER_ID       4        Y      0
# 1                  DV_HOSPITAL_INFO_EDW_HOSPITAL_NAME      50        Y      0
# 2                                             ADDRESS      50        Y      0
# 3                                                CITY      20        Y      0
# 4                                               STATE       2        Y      0
# 5                                            ZIP_CODE       4        Y      0
# 6                                         COUNTY_NAME      20        Y      0
# 7                                       HOSPITAL_TYPE      25        Y      0
# 8                                  HOSPITAL_OWNERSHIP      43        Y      0
# 9                                  EMERGENCY_SERVICES       3        Y      0
# 10          MEETS_CRITERIA_FOR_MEANINGFUL_USE_OF_EHRS       1        Y      0
# 11                            HOSPITAL_OVERALL_RATING      13        Y      0
# 12                   HOSPITAL_OVERALL_RATING_FOOTNOTE     149        Y      0
# 13                      MORTALITY_NATIONAL_COMPARISON      28        Y      0
# 14             MORTALITY_NATIONAL_COMPARISON_FOOTNOTE     149        Y      0
# 15                 SAFETY_OF_CARE_NATIONAL_COMPARISON      28        Y      0
# 16        SAFETY_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE     149        Y      0
# 17                    READMISSION_NATIONAL_COMPARISON      28        Y      0
# 18           READMISSION_NATIONAL_COMPARISON_FOOTNOTE     149        Y      0
# 19             PATIENT_EXPERIENCE_NATIONAL_COMPARISON      28        Y      0
# 20    PATIENT_EXPERIENCE_NATIONAL_COMPARISON_FOOTNOTE     139        Y      0
# 21          EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON      28        Y      0
# 22  EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON_FOOT...     139        Y      0
# 23             TIMELINESS_OF_CARE_NATIONAL_COMPARISON      28        Y      0
# 24    TIMELINESS_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE     139        Y      0
# 25  EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMP...      28        Y      0
# 26  EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMP...     149        Y      0
# 27         DV_HOSPITAL_READMISSION_DB2S_HOSPITAL_NAME    2048        Y      0
# 28                                       MEASURE_NAME    2048        Y      0
# 29                               NUMBER_OF_DISCHARGES    2048        Y      0
# 30                                           FOOTNOTE       4        Y      0
# 31                           EXCESS_READMISSION_RATIO    2048        Y      0
# 32                         PREDICTED_READMISSION_RATE    2048        Y      0
# 33                          EXPECTED_READMISSION_RATE       8        Y      0
# 34                             NUMBER_OF_READMISSIONS       4        Y      0
# 35                                         START_DATE    2048        Y      0
# 36                                           END_DATE    2048        Y      0
#
#    TYPENAME TYPESCHEMA
# 0   INTEGER   SYSIBM
# 1   VARCHAR   SYSIBM
# 2   VARCHAR   SYSIBM
# 3   VARCHAR   SYSIBM
# 4   VARCHAR   SYSIBM
# 5   INTEGER   SYSIBM
# 6   VARCHAR   SYSIBM
# 7   VARCHAR   SYSIBM
# 8   VARCHAR   SYSIBM
# 9   VARCHAR   SYSIBM
# 10  VARCHAR   SYSIBM
# 11  VARCHAR   SYSIBM
# 12  VARCHAR   SYSIBM
# 13  VARCHAR   SYSIBM
# 14  VARCHAR   SYSIBM
# 15  VARCHAR   SYSIBM
# 16  VARCHAR   SYSIBM
# 17  VARCHAR   SYSIBM
# 18  VARCHAR   SYSIBM
# 19  VARCHAR   SYSIBM
# 20  VARCHAR   SYSIBM
# 21  VARCHAR   SYSIBM
# 22  VARCHAR   SYSIBM
# 23  VARCHAR   SYSIBM
# 24  VARCHAR   SYSIBM
# 25  VARCHAR   SYSIBM
# 26  VARCHAR   SYSIBM
# 27  VARCHAR   SYSIBM
# 28  VARCHAR   SYSIBM
# 29  VARCHAR   SYSIBM
# 30  INTEGER   SYSIBM
# 31  VARCHAR   SYSIBM
# 32  VARCHAR   SYSIBM
# 33   DOUBLE   SYSIBM
# 34  INTEGER   SYSIBM
# 35  VARCHAR   SYSIBM
# 36  VARCHAR   SYSIBM

# %%
response.json()
# Out:
# {'jobStatus': 4,
#  'jobStatusDescription': 'Job is complete',
#  'resultSet': [{'COLNAME': 'PROVIDER_ID',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'DV_HOSPITAL_INFO_EDW_HOSPITAL_NAME',
#    'LENGTH': 50,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'ADDRESS',
#    'LENGTH': 50,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'CITY',
#    'LENGTH': 20,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'STATE',
#    'LENGTH': 2,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'ZIP_CODE',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'COUNTY_NAME',
#    'LENGTH': 20,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_TYPE',
#    'LENGTH': 25,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_OWNERSHIP',
#    'LENGTH': 43,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EMERGENCY_SERVICES',
#    'LENGTH': 3,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MEETS_CRITERIA_FOR_MEANINGFUL_USE_OF_EHRS',
#    'LENGTH': 1,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_OVERALL_RATING',
#    'LENGTH': 13,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_OVERALL_RATING_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MORTALITY_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MORTALITY_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'SAFETY_OF_CARE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'SAFETY_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'READMISSION_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'READMISSION_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'PATIENT_EXPERIENCE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'PATIENT_EXPERIENCE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 139,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 139,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'TIMELINESS_OF_CARE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'TIMELINESS_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 139,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'DV_HOSPITAL_READMISSION_DB2S_HOSPITAL_NAME',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MEASURE_NAME',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'NUMBER_OF_DISCHARGES',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'FOOTNOTE',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EXCESS_READMISSION_RATIO',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'PREDICTED_READMISSION_RATE',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EXPECTED_READMISSION_RATE',
#    'LENGTH': 8,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'DOUBLE',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'NUMBER_OF_READMISSIONS',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'START_DATE',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'END_DATE',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '}],
#  'rowCount': 37}
