# %% [markdown]
# # Query Data Virtualization using the REST API

# %% [markdown]
# The following notebook shows some examles of the same queries that I list in the September 2021 db2dean.com article on how to use the Data Virtualization REST API for querying virtual tables.  The difference is that the article calls the REST API using cURL and this notebook uses Python.
#
#
# You can find more information about the Db2/DV REST API at: https://www.ibm.com/support/producthub/db2/docs/content/SSEPGG_11.5.0/com.ibm.db2.luw.admin.rest.doc/doc/c_rest.html.
#
# This notebook is based on the one Peter Kohlmann provides in his Jupyter notebook on GitHub and uses much of the descriptive text used there.  He also provides many more examples that you can see here:  https://github.com/Db2-DTE-POC/CPDDVLAB/blob/master/Bonus%20Lab%20-%20Db2%20RESTful%20Endpoint%20Service.ipynb

# %% [markdown]
# ### Import the required programming libraries
# The requests library is the minimum required by Python to construct RESTful service calls. The Pandas library is used to format and manipulate JSON result sets as tables.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Authenticate to the End Point and Get a Token used for Querying Data
# So that you don't have to send your user id and password with every query, the REST endpoint will allow you to call it once and give  you a token to use in the queries instead.  The next set of steps will configure and call an API giving the End Point your Data Virtualization user id, pass word and other information to get a token that can be used to authenticate when you run the API go query the database.

# %% [markdown]
# ### Create the Header File required for getting an authetication token
# The RESTful call to the RESTful Endpoint service is contructed and transmitted as JSON. The first part of the JSON structure is the headers that define the content tyoe of the request.

# %% [markdown]
# Please note that you must configure the REST Endpoint as described in my Db2 Rest Endpoint article unless you are using the DV Endpoint deployed in your Cloud Pak for Data cluster.  In this case I am using my own endpoint an not the one in the CPD cluster.  http://www.db2dean.com/Previous/Db2RestEndpoint.html

# %%
headers = {
  "content-type": "application/json"
}

# %% [markdown]
# ### RESTful Host
# Define the host and port of the end point in a URL.    In this case I'm using my own endpoint

# %%
Db2RESTful = "http://192.168.0.14:50050"

# %% [markdown]
# ### API Authentication Service
# Each service has its own path in the RESTful call. For authentication we need to point to the `v1/auth` service.

# %%
API_Auth = "/v1/auth"

# %% [markdown]
# ### Authentication
# To authenticate to the RESTful service you must provide the connection information for the Data Virtualization database you want to query along with the userid and password that you are using to authenticate to that database. You can also provide an expiry time so that the access token that gets returned will be invalidated after that time period. In this example the token is good for 30 minutes.  Note that the database name in DV is always "BIGSQL".

# %%
body = {
  "dbParms": {
    "dbHost": "cpdmkt-cpd-cpdmkt.apps.cpd.170-224-51-161.nip.io",
    "dbName": "BIGSQL",
    "dbPort": 30753,
    "isSSLConnection": False,
    "username": "db2dean",
    "password": "password"
  },
  "expiryTime": "30m"
}

# %% [markdown]
# ### API Service
# When communicating with the RESTful service, you must provide the name of the service that you want to interact with. In this case the authentication service is */v1/auth*.   When the cell below is run, the server will establish a connection to the database server.

# %%
# Use with HTTP call (when using endpoint container on my mac)
# Use when querying my local sample db or the DV database in the CPD cluster.
try:
    response = requests.post("{}{}".format(Db2RESTful,API_Auth), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

# %% [markdown]
# ### curl eqluivilant to the above call:
# token=`curl --header "Content-Type: application/json" \
#              -d '{"dbParms":{"dbHost": "cpdmkt-cpd-cpdmkt.apps.cpd.170-224-51-161.nip.io", \
# 		  "dbName": "BIGSQL","dbPort": 30753 ,\
#                   "isSSLConnection":false,"username": "db2dean","password": "password"},"expiryTime": "30m"}' \
#              http://192.168.0.14:50050/v1/auth`
#
# token2=`echo $token | awk 'BEGIN {FS = "\""} ; {print $4}'

# %% [markdown]
# A response code of 200 means that the authentication worked properly, otherwise the error that was generated is printed.

# %%
print(response)
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %% [markdown]
# The response includes a connection token that is reused in the queries below. It ensures secure a connection without requiring that you reenter a userid and password with each request.

# %%
if (response.status_code == 200):
  token = response.json()["token"]
  print("Token: {}".format(token))
else: 
  print(response.json()["errors"])
# Out:
# Token: eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJhZG1pbiI6dHJ1ZSwiY2xpZW50X2lkIjoiOTQzOTk2NzMtMDhiYy00NGIxLTlhMTEtZmRhYTY4NTFjZDQwIiwiZXhwIjoxNjMyNzc5NTcwLCJpc3MiOiJkYjJkZWFuIn0.Go038g4gOe1P8qw5QI5-L9nrgJHTlQOw_dr5VeMsNKynZnXKa57vRfFDubjBK-4PL1c0c9XDwimfvq1jT8ZqP60B2I1onemJYPc7OIr2f6rbAxVqBFGd6BSSNwwTvd-auZj6otqLjWCw-HOMseCivO1RU_agijUT0Jbo5kQc27EICU-nI-rZRg4ho367ndbVwrtfqxVNPtjgqaJSkkLcbaHXvKomtAtMHzz0FjsR_kelgetrncaCLHsWPkYIozVE0dJgbAoJNUX16ml3S_tfOEBY0d1I9mQdFMP-0Z3ekLAKgBBnJkIib6J1_ll342Te3Sm2smRZZytv2yiVySmnHQ

# %% [markdown]
# ## The remaining steps configure variables and then query the database
# The standard header for all subsequent calls will use this format. It includes the access token.

# %%
headers = {
  "authorization": f"{token}",
  "content-type": "application/json"
}

# %% [markdown]
# ### API for Querying the virtual dataase
# Executing SQL requires the execsql service endpoint.

# %%
API_execsql = "/v1/services/execsql"

# %% [markdown]
# ### Format string to query a single virtual table in the database and run it

# %%
body = {
  "isQuery": True,
  "sqlStatement": "SELECT * \
    FROM DV.HOSPITAL_HCAHPS_DATA_PG \
    fetch first 3 rows only",
  "sync": True
}

# %%
try:
    response = requests.post("{}{}".format(Db2RESTful,API_execsql), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

    # A response of 200 means success
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# #### The equivalent cURL of the above call is shown in this shell script
#
# ```
# myquery= "SELECT * \
#     FROM DV.HOSPITAL_HCAHPS_DATA_PG"
# ```
# ```
# curl --header "authorization: $token2" --header 'Content-Type: application/json' \
#       -d '{"isQuery": true,"sqlStatement": "'"$myquery"'" ,"sync": true}' \
#      http://192.168.0.14:50050/v1/services/execsql
# ```

# %% [markdown]
# Retrieve the results. The Dataframe class converts the json result set into a table. Dataframes can be used to further manipulate results in Python.

# %%
display(pd.DataFrame(response.json()['resultSet']))
# Out:
#        HCAHPS_MEASURE_ID PROVIDER_ID           county_name  \
# 0  H_COMP_4_LINEAR_SCORE       90008  DISTRICT OF COLUMBIA
# 1          H_COMP_4_SN_P       90008  DISTRICT OF COLUMBIA
# 2           H_COMP_4_U_P      100009            MIAMI-DADE
#
#                          hcahps_answer_description hcahps_answer_percent  \
# 0              Pain management - linear mean score        Not Applicable
# 1  Pain was "sometimes" or "never" well controlled                    17
# 2               Pain was "usually" well controlled                    23
#
#   hcahps_answer_percent_footnote hcahps_linear_mean_value  \
# 0                                                      81
# 1                                          Not Applicable
# 2                                          Not Applicable
#
#                                      hcahps_question  \
# 0                Pain management - linear mean score
# 1  Patients who reported that their pain was "Som...
# 2  Patients who reported that their pain was "Usu...
#
#                   hospital_name
# 0         UNITED MEDICAL CENTER
# 1         UNITED MEDICAL CENTER
# 2  UNIVERSITY OF MIAMI HOSPITAL

# %%
response.json()
# Out:
# {'jobStatus': 4,
#  'jobStatusDescription': 'Job is complete',
#  'resultSet': [{'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'PROVIDER_ID': '90008',
#    'county_name': 'DISTRICT OF COLUMBIA',
#    'hcahps_answer_description': 'Pain management - linear mean score',
#    'hcahps_answer_percent': 'Not Applicable',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': '81',
#    'hcahps_question': 'Pain management - linear mean score',
#    'hospital_name': 'UNITED MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_SN_P',
#    'PROVIDER_ID': '90008',
#    'county_name': 'DISTRICT OF COLUMBIA',
#    'hcahps_answer_description': 'Pain was "sometimes" or "never" well controlled',
#    'hcahps_answer_percent': '17',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Sometimes" or "Never" well controlled',
#    'hospital_name': 'UNITED MEDICAL CENTER'},
#   {'HCAHPS_MEASURE_ID': 'H_COMP_4_U_P',
#    'PROVIDER_ID': '100009',
#    'county_name': 'MIAMI-DADE',
#    'hcahps_answer_description': 'Pain was "usually" well controlled',
#    'hcahps_answer_percent': '23',
#    'hcahps_answer_percent_footnote': '',
#    'hcahps_linear_mean_value': 'Not Applicable',
#    'hcahps_question': 'Patients who reported that their pain was "Usually" well controlled',
#    'hospital_name': 'UNIVERSITY OF MIAMI HOSPITAL'}],
#  'rowCount': 3}

# %% [markdown]
# ### Format string to join multiple tables and run it

# %%
body = {
  "isQuery": True,
  "sqlStatement": "select postgres.hcahps_measure_id \
              , db2edw.county_name as County \
              , sandbox.number_of_readmissions \
           from DV.HOSPITAL_HCAHPS_DATA_PG postgres \
              , DV.HOSPITAL_INFO_EDW db2edw \
              , DV.HOSPITAL_READMISSION_DB2S sandbox \
          where varchar(postgres.provider_id) = db2edw.provider_id \
            and db2edw.provider_id = sandbox.provider_number \
          fetch first 3 rows only",
  "sync": True
}

# %% [markdown]
# Retrieve the results. The Dataframe class converts the json result set into a table. Dataframes can be used to further manipulate results in Python.

# %%
# Use with HTTP call when using endpoint container on my mac
# This end point tals to my local DB, DV or any other database defined in the DB2RESTful set up above.
try:
    response = requests.post("{}{}".format(Db2RESTful,API_execsql), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

    # A response of 200 means success
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# The equivalent cURL call is:
#
# ```
# myquery="select postgres.hcahps_measure_id \
#               , db2edw.county_name as County \
#               , sandbox.number_of_readmissions \
#            from DV.HOSPITAL_HCAHPS_DATA_PG postgres \
#               , DV.HOSPITAL_INFO_EDW db2edw \
#               , DV.HOSPITAL_READMISSION_DB2S sandbox \
#           where varchar(postgres.provider_id) = db2edw.provider_id \
#             and db2edw.provider_id = sandbox.provider_number \
#           fetch first 3 rows only"
#
# curl --header "authorization: $token2" --header 'Content-Type: application/json' \
#       -d '{"isQuery": true,"sqlStatement": "'"$myquery"'" ,"sync": true}' \
#      http://192.168.0.14:50050/v1/services/execsql
# ```

# %%
display(pd.DataFrame(response.json()['resultSet']))
# Out:
#                  COUNTY      HCAHPS_MEASURE_ID  NUMBER_OF_READMISSIONS
# 0  DISTRICT OF COLUMBIA  H_COMP_4_LINEAR_SCORE                      61
# 1  DISTRICT OF COLUMBIA  H_COMP_4_LINEAR_SCORE                      44
# 2  DISTRICT OF COLUMBIA  H_COMP_4_LINEAR_SCORE                      40

# %%
response.json()
# Out:
# {'jobStatus': 4,
#  'jobStatusDescription': 'Job is complete',
#  'resultSet': [{'COUNTY': 'DISTRICT OF COLUMBIA',
#    'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'NUMBER_OF_READMISSIONS': 61},
#   {'COUNTY': 'DISTRICT OF COLUMBIA',
#    'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'NUMBER_OF_READMISSIONS': 44},
#   {'COUNTY': 'DISTRICT OF COLUMBIA',
#    'HCAHPS_MEASURE_ID': 'H_COMP_4_LINEAR_SCORE',
#    'NUMBER_OF_READMISSIONS': 40}],
#  'rowCount': 3}

# %% [markdown]
# ### Format string to describe a virtual table

# %%
body = {
  "isQuery": True,
  "sqlStatement": "CALL sysproc.admin_cmd('describe table DV.HOSP_INFO_READMIT_VIEW')",
  "sync": True
}

# %%
# Use with HTTP call when using endpoint container on my mac
# This end point tals to my local DB, DV or any other database defined in the DB2RESTful set up above.
try:
    response = requests.post("{}{}".format(Db2RESTful,API_execsql), headers=headers, json=body)
except Exception as e:
    print("Unable to call RESTful service. Error={}".format(repr(e)))

    # A response of 200 means success
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# The equivalent cURL call is:
# ```
# myquery="CALL sysproc.admin_cmd('describe table DV.HOSP_INFO_READMIT_VIEW ')"
# curl --header "authorization: $token2" --header 'Content-Type: application/json' \
#       -d '{"isQuery": true,"sqlStatement": "'"$myquery"'" ,"sync": true}' \
#      http://192.168.0.14:50050/v1/services/execsql
# ```

# %% [markdown]
# Retrieve the results. The Dataframe class converts the json result set into a table. Dataframes can be used to further manipulate results in Python.

# %%
display(pd.DataFrame(response.json()['resultSet']))
# Out:
#                                               COLNAME  LENGTH NULLABLE  SCALE  \
# 0                                         PROVIDER_ID       4        Y      0
# 1                  DV_HOSPITAL_INFO_EDW_HOSPITAL_NAME      50        Y      0
# 2                                             ADDRESS      50        Y      0
# 3                                                CITY      20        Y      0
# 4                                               STATE       2        Y      0
# 5                                            ZIP_CODE       4        Y      0
# 6                                         COUNTY_NAME      20        Y      0
# 7                                       HOSPITAL_TYPE      25        Y      0
# 8                                  HOSPITAL_OWNERSHIP      43        Y      0
# 9                                  EMERGENCY_SERVICES       3        Y      0
# 10          MEETS_CRITERIA_FOR_MEANINGFUL_USE_OF_EHRS       1        Y      0
# 11                            HOSPITAL_OVERALL_RATING      13        Y      0
# 12                   HOSPITAL_OVERALL_RATING_FOOTNOTE     149        Y      0
# 13                      MORTALITY_NATIONAL_COMPARISON      28        Y      0
# 14             MORTALITY_NATIONAL_COMPARISON_FOOTNOTE     149        Y      0
# 15                 SAFETY_OF_CARE_NATIONAL_COMPARISON      28        Y      0
# 16        SAFETY_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE     149        Y      0
# 17                    READMISSION_NATIONAL_COMPARISON      28        Y      0
# 18           READMISSION_NATIONAL_COMPARISON_FOOTNOTE     149        Y      0
# 19             PATIENT_EXPERIENCE_NATIONAL_COMPARISON      28        Y      0
# 20    PATIENT_EXPERIENCE_NATIONAL_COMPARISON_FOOTNOTE     139        Y      0
# 21          EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON      28        Y      0
# 22  EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON_FOOT...     139        Y      0
# 23             TIMELINESS_OF_CARE_NATIONAL_COMPARISON      28        Y      0
# 24    TIMELINESS_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE     139        Y      0
# 25  EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMP...      28        Y      0
# 26  EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMP...     149        Y      0
# 27         DV_HOSPITAL_READMISSION_DB2S_HOSPITAL_NAME    2048        Y      0
# 28                                       MEASURE_NAME    2048        Y      0
# 29                               NUMBER_OF_DISCHARGES    2048        Y      0
# 30                                           FOOTNOTE       4        Y      0
# 31                           EXCESS_READMISSION_RATIO    2048        Y      0
# 32                         PREDICTED_READMISSION_RATE    2048        Y      0
# 33                          EXPECTED_READMISSION_RATE       8        Y      0
# 34                             NUMBER_OF_READMISSIONS       4        Y      0
# 35                                         START_DATE    2048        Y      0
# 36                                           END_DATE    2048        Y      0
#
#    TYPENAME TYPESCHEMA
# 0   INTEGER   SYSIBM
# 1   VARCHAR   SYSIBM
# 2   VARCHAR   SYSIBM
# 3   VARCHAR   SYSIBM
# 4   VARCHAR   SYSIBM
# 5   INTEGER   SYSIBM
# 6   VARCHAR   SYSIBM
# 7   VARCHAR   SYSIBM
# 8   VARCHAR   SYSIBM
# 9   VARCHAR   SYSIBM
# 10  VARCHAR   SYSIBM
# 11  VARCHAR   SYSIBM
# 12  VARCHAR   SYSIBM
# 13  VARCHAR   SYSIBM
# 14  VARCHAR   SYSIBM
# 15  VARCHAR   SYSIBM
# 16  VARCHAR   SYSIBM
# 17  VARCHAR   SYSIBM
# 18  VARCHAR   SYSIBM
# 19  VARCHAR   SYSIBM
# 20  VARCHAR   SYSIBM
# 21  VARCHAR   SYSIBM
# 22  VARCHAR   SYSIBM
# 23  VARCHAR   SYSIBM
# 24  VARCHAR   SYSIBM
# 25  VARCHAR   SYSIBM
# 26  VARCHAR   SYSIBM
# 27  VARCHAR   SYSIBM
# 28  VARCHAR   SYSIBM
# 29  VARCHAR   SYSIBM
# 30  INTEGER   SYSIBM
# 31  VARCHAR   SYSIBM
# 32  VARCHAR   SYSIBM
# 33   DOUBLE   SYSIBM
# 34  INTEGER   SYSIBM
# 35  VARCHAR   SYSIBM
# 36  VARCHAR   SYSIBM

# %%
response.json()
# Out:
# {'jobStatus': 4,
#  'jobStatusDescription': 'Job is complete',
#  'resultSet': [{'COLNAME': 'PROVIDER_ID',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'DV_HOSPITAL_INFO_EDW_HOSPITAL_NAME',
#    'LENGTH': 50,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'ADDRESS',
#    'LENGTH': 50,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'CITY',
#    'LENGTH': 20,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'STATE',
#    'LENGTH': 2,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'ZIP_CODE',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'COUNTY_NAME',
#    'LENGTH': 20,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_TYPE',
#    'LENGTH': 25,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_OWNERSHIP',
#    'LENGTH': 43,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EMERGENCY_SERVICES',
#    'LENGTH': 3,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MEETS_CRITERIA_FOR_MEANINGFUL_USE_OF_EHRS',
#    'LENGTH': 1,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_OVERALL_RATING',
#    'LENGTH': 13,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'HOSPITAL_OVERALL_RATING_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MORTALITY_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MORTALITY_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'SAFETY_OF_CARE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'SAFETY_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'READMISSION_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'READMISSION_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'PATIENT_EXPERIENCE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'PATIENT_EXPERIENCE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 139,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFECTIVENESS_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 139,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'TIMELINESS_OF_CARE_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'TIMELINESS_OF_CARE_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 139,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMPARISON',
#    'LENGTH': 28,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EFFICIENT_USE_OF_MEDICAL_IMAGING_NATIONAL_COMPARISON_FOOTNOTE',
#    'LENGTH': 149,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'DV_HOSPITAL_READMISSION_DB2S_HOSPITAL_NAME',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'MEASURE_NAME',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'NUMBER_OF_DISCHARGES',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'FOOTNOTE',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EXCESS_READMISSION_RATIO',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'PREDICTED_READMISSION_RATE',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'EXPECTED_READMISSION_RATE',
#    'LENGTH': 8,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'DOUBLE',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'NUMBER_OF_READMISSIONS',
#    'LENGTH': 4,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'INTEGER',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'START_DATE',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '},
#   {'COLNAME': 'END_DATE',
#    'LENGTH': 2048,
#    'NULLABLE': 'Y',
#    'SCALE': 0,
#    'TYPENAME': 'VARCHAR',
#    'TYPESCHEMA': 'SYSIBM  '}],
#  'rowCount': 37}
